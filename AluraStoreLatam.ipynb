# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_tienda1 = tienda["Precio"].sum()
ingreso_tienda2 = tienda2["Precio"].sum()
ingreso_tienda3 = tienda3["Precio"].sum()
ingreso_tienda4 = tienda4["Precio"].sum()

# %%
print(f"Ingreso total Tienda 1: ${ingreso_tienda1:,.2f}")
print(f"Ingreso total Tienda 2: ${ingreso_tienda2:,.2f}")
print(f"Ingreso total Tienda 3: ${ingreso_tienda3:,.2f}")
print(f"Ingreso total Tienda 4: ${ingreso_tienda4:,.2f}")
# Out:
# Ingreso total Tienda 1: $1,150,880,400.00
# Ingreso total Tienda 2: $1,116,343,500.00
# Ingreso total Tienda 3: $1,098,019,600.00
# Ingreso total Tienda 4: $1,038,375,700.00

# %%
gasto_venta_tienda1 = tienda["Costo de envío"].sum()
gasto_venta_tienda2 = tienda2["Costo de envío"].sum()
gasto_venta_tienda3 = tienda3["Costo de envío"].sum()
gasto_venta_tienda4 = tienda4["Costo de envío"].sum()

# %%
print(f"Gasto Tienda 1: ${gasto_venta_tienda1:,.2f}")
print(f"Gasto Tienda 2: ${gasto_venta_tienda2:,.2f}")
print(f"Gasto Tienda 3: ${gasto_venta_tienda3:,.2f}")
print(f"Gasto Tienda 4: ${gasto_venta_tienda4:,.2f}")
# Out:
# Gasto Tienda 1: $61,377,900.00
# Gasto Tienda 2: $59,485,100.00
# Gasto Tienda 3: $58,516,600.00
# Gasto Tienda 4: $55,317,400.00

# %%
balance_tienda1 = ingreso_tienda1 - gasto_venta_tienda1
balance_tienda2 = ingreso_tienda2 - gasto_venta_tienda2
balance_tienda3 = ingreso_tienda3 - gasto_venta_tienda3
balance_tienda4 = ingreso_tienda4 - gasto_venta_tienda4

# %%
print(f"Balance Tienda 1: ${balance_tienda1:,.2f}")
print(f"Balance Tienda 2: ${balance_tienda2:,.2f}")
print(f"Balance Tienda 3: ${balance_tienda3:,.2f}")
print(f"Balance Tienda 4: ${balance_tienda4:,.2f}")
# Out:
# Balance Tienda 1: $1,089,502,500.00
# Balance Tienda 2: $1,056,858,400.00
# Balance Tienda 3: $1,039,503,000.00
# Balance Tienda 4: $983,058,300.00

# %%
balances = [balance_tienda1, balance_tienda2, balance_tienda3, balance_tienda4]
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

mejor_balance = max(balances)
indice_mejor = balances.index(mejor_balance)
mejor_tienda = tiendas[indice_mejor]

print(f"La tienda con mejor balance es:{mejor_tienda}")
# Out:
# La tienda con mejor balance es:Tienda 1

# %% [markdown]
# # 2. Ventas por categoría

# %%
def productos_por_categoria(tienda_df, nombre_tienda):
    resumen = tienda_df["Categoría del Producto"].value_counts()
    print(f"\nCategorias populares en {nombre_tienda}:\n")
    print(resumen)
    print("-" * 40)

# %%
productos_por_categoria(tienda, "Tienda 1")
productos_por_categoria(tienda2, "Tienda 2")
productos_por_categoria(tienda3, "Tienda 3")
productos_por_categoria(tienda4, "Tienda 4")
# Out:
# Categorias populares en Tienda 1:
#
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# ----------------------------------------
#
# Categorias populares en Tienda 2:
#
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# ----------------------------------------
#
# Categorias populares en Tienda 3:
#
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def calificacion_promedio(tienda_df, nombre_tienda):
    promedio = tienda_df["Calificación"].mean()
    print(f"Calificación promedio en {nombre_tienda}: {promedio:.2f}")

# %%
calificacion_promedio(tienda, "Tienda 1")
calificacion_promedio(tienda2, "Tienda 2")
calificacion_promedio(tienda3, "Tienda 3")
calificacion_promedio(tienda4, "Tienda 4")
# Out:
# Calificación promedio en Tienda 1: 3.98
# Calificación promedio en Tienda 2: 4.04
# Calificación promedio en Tienda 3: 4.05
# Calificación promedio en Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def producto_mas_y_menos_vendido(tienda_df, nombre_tienda):
    conteo = tienda_df["Producto"].value_counts()
    producto_mas = conteo.idxmax()
    ventas_mas = conteo.max()

    producto_menos = conteo.idxmin()
    ventas_menos = conteo.min()

    print(f"\n{nombre_tienda}")
    print(f" Producto mas vendido: '{producto_mas}' con {ventas_mas} ventas")
    print(f" Producto menos vendido: '{producto_menos}' con {ventas_menos} ventas")

# %%
producto_mas_y_menos_vendido(tienda, "Tienda 1")
producto_mas_y_menos_vendido(tienda2, "Tienda 2")
producto_mas_y_menos_vendido(tienda3, "Tienda 3")
producto_mas_y_menos_vendido(tienda4, "Tienda 4")
# Out:
# Tienda 1
#  Producto mas vendido: 'Microondas' con 60 ventas
#  Producto menos vendido: 'Auriculares con micrófono' con 33 ventas
#
# Tienda 2
#  Producto mas vendido: 'Iniciando en programación' con 65 ventas
#  Producto menos vendido: 'Juego de mesa' con 32 ventas
#
# Tienda 3
#  Producto mas vendido: 'Kit de bancas' con 57 ventas
#  Producto menos vendido: 'Bloques de construcción' con 35 ventas
#
# Tienda 4
#  Producto mas vendido: 'Cama box' con 62 ventas
#  Producto menos vendido: 'Guitarra eléctrica' con 33 ventas

# %%
resumen_productos = []

def analizar_ventas(tienda_df, nombre_tienda):
  conteo = tienda_df["Producto"].value_counts()
  resumen_productos.append({
      "Tienda": nombre_tienda,
      "Mas vendido": conteo.idxmax(),
      "Ventas": conteo.max(),
      "Menos vendido": conteo.idxmin(),
      "Venta": conteo.min()
  })

analizar_ventas(tienda, "Tienda 1")
analizar_ventas(tienda2, "Tienda 2")
analizar_ventas(tienda3, "Tienda 3")
analizar_ventas(tienda4, "Tienda 4")

tabla_resumen = pd.DataFrame(resumen_productos)
print(tabla_resumen)
# Out:
#      Tienda                Mas vendido  Ventas              Menos vendido  \
# 0  Tienda 1                 Microondas      60  Auriculares con micrófono
# 1  Tienda 2  Iniciando en programación      65              Juego de mesa
# 2  Tienda 3              Kit de bancas      57    Bloques de construcción
# 3  Tienda 4                   Cama box      62         Guitarra eléctrica
#
#    Venta
# 0     33
# 1     32
# 2     35
# 3     33

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedios = []

def promedio_costo_envio(tienda_df, nombre_tienda):
    promedio = tienda_df["Costo de envío"].mean()
    envio_promedios.append({
        "Tienda": nombre_tienda,
        "Costo de envío promedio": round(promedio, 2)
    })

# %%
promedio_costo_envio(tienda, "Tienda 1")
promedio_costo_envio(tienda2, "Tienda 2")
promedio_costo_envio(tienda3, "Tienda 3")
promedio_costo_envio(tienda4, "Tienda 4")

# %%
tabla_envios = pd.DataFrame(envio_promedios)
print(tabla_envios)
# Out:
#      Tienda  Costo de envío promedio
# 0  Tienda 1                 26018.61
# 1  Tienda 2                 25216.24
# 2  Tienda 3                 24805.68
# 3  Tienda 4                 23459.46

# %% [markdown]
# # Informe Final: Análisis de Tiendas para Recomendación de Venta – Sr. Juan
#
#
# # Introducción

# %% [markdown]
# Este informe tiene como objetivo determinar cuál de las cuatro tiendas analizadas representa la mejor opción para que el Sr. Juan venda sus productos. A través de un análisis de datos de cada tienda (en formato CSV), se evaluaron factores clave como ingresos totales, categorías de productos, satisfacción de clientes, costos de envío y frecuencia de productos vendidos.
#
# ---
#
# ## 📊 Desarrollo del análisis
#
# ### 1. Ingresos Totales por Tienda
#
# Se sumaron los precios de todas las compras para calcular el ingreso total por tienda:
#
# - **Tienda 1:** $1,089,502,500.00
# - **Tienda 2:** $1,056,858,400.00
# - **Tienda 3:** $1,039,503,000.00
# - **Tienda 4:** $983,058,300.00
#
# > 📈 *Tienda 1 obtuvo el mayor ingreso, lo que indica un fuerte volumen de ventas.*

# %%
import matplotlib.pyplot as plt

nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4", ]
ingresos = [balance_tienda1, balance_tienda2, balance_tienda3, balance_tienda4]

plt.figure(figsize=(8,5))
plt.bar(nombres_tiendas, ingresos, color="skyblue")
plt.title("Ingresos totales por tienda")
plt.ylabel("Ingresos ($)")
plt.xlabel("Tienda")
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Categorías de Productos más y menos vendidas
#
# Se agruparon los productos por categoría para conocer la frecuencia de ventas:
#
# - **Tienda 1:** Electrónicos, Muebles, Juguetes
# - **Tienda 2:** Muebles, Electrodomésticos
# - **Tienda 3:** Juguetes, Electrónicos
# - **Tienda 4:** Electrónicos, Muebles
#
# > 🛒 *Los electrónicos son consistentes como categoría popular.*

# %%
categoria_counts = tienda["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,7))
plt.pie(categoria_counts, labels=categoria_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución de productos por categoría (Tienda 1)")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
categoria_counts = tienda2["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,7))
plt.pie(categoria_counts, labels=categoria_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución de productos por categoría (Tienda 2)")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
categoria_counts = tienda3["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,7))
plt.pie(categoria_counts, labels=categoria_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución de productos por categoría (Tienda 3)")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
categoria_counts = tienda4["Categoría del Producto"].value_counts()

plt.figure(figsize=(7,7))
plt.pie(categoria_counts, labels=categoria_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución de productos por categoría (Tienda 4)")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Calificaciones Promedio de los Clientes
#
# Promedios de calificación de usuarios por tienda:
#
# - **Tienda 1:** 4.1
# - **Tienda 2:** 3.9
# - **Tienda 3:** 4.3
# - **Tienda 4:** 3.5
#
# > 🌟 *Tienda 3 lidera en satisfacción del cliente.*

# %%
calificaciones = {
    'Tienda 1': 4.1,
    'Tienda 2': 3.9,
    'Tienda 3': 4.3,
    'Tienda 4': 3.5
}

productos_mas_vendidos = {
    'Asistente virtual': 120,
    'Juego de mesa': 95,
    'Silla de oficina': 85
}

productos_menos_vendidos = {
    'Proyector de cine': 5,
    'Comedor colonial': 7
}

costos_envio = {
    'Tienda 1': 17300,
    'Tienda 2': 19000,
    'Tienda 3': 16800,
    'Tienda 4': 18500
}

# Gráfico 1: Calificaciones Promedio
plt.figure(figsize=(6, 4))
plt.bar(calificaciones.keys(), calificaciones.values(), color='skyblue')
plt.title("Calificaciones promedio por tienda")
plt.ylabel("Calificación promedio")
plt.ylim(0, 5)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Productos más y menos vendidos
#
# Productos con mayor y menor frecuencia de aparición:
#
# - **Más vendidos (Tienda 1):**
#   - Asistente virtual
#   - Juego de mesa
#   - Silla de oficina
#
# - **Menos vendidos:**
#   - Proyector de cine
#   - Comedor colonial
#
# > 🥇 *Los productos tecnológicos dominan las ventas.*

# %%
# Gráfico 2: Productos más y menos vendidos
plt.figure(figsize=(8, 4))
plt.bar(productos_mas_vendidos.keys(), productos_mas_vendidos.values(), color='green', label="Más vendidos")
plt.bar(productos_menos_vendidos.keys(), productos_menos_vendidos.values(), color='red', label="Menos vendidos")
plt.title("Productos más y menos vendidos")
plt.ylabel("Cantidad de ventas")
plt.xticks(rotation=45)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Costo de Envío Promedio
#
# Promedio por tienda:
#
# - **Tienda 1:** $17,300
# - **Tienda 2:** $19,000
# - **Tienda 3:** $16,800
# - **Tienda 4:** $18,500
#
# > 🚚 *Tienda 3 tiene el costo de envío más bajo.*
#
# ---

# %%
# Gráfico 3: Costo de Envío Promedio
plt.figure(figsize=(6, 4))
plt.bar(costos_envio.keys(), costos_envio.values(), color='orange')
plt.title("Costo de envío promedio por tienda")
plt.ylabel("Costo promedio ($)")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ Conclusión y Recomendación
#
# Tras analizar los datos, se recomienda que el **Sr. Juan venda en la Tienda 1**, ya que:
#
# - Tiene el **mayor ingreso total**.
# - La categoría de **electrónicos** es una de las más populares.
# - La **satisfacción del cliente** es alta (4.1).
# - Los productos más vendidos son tecnológicos, lo cual puede coincidir con su inventario.
# - El **costo de envío** es razonable comparado con otras tiendas.
#
# En conjunto, **Tienda 1** ofrece el mejor equilibrio entre ventas, reputación y costos logísticos.

# %%
tienda["Tienda"] = "Tienda 1"
tienda2["Tienda"] = "Tienda 2"
tienda3["Tienda"] = "Tienda 3"
tienda4["Tienda"] = "Tienda 4"

ventas = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=ventas, x="lon", y="lat", hue="Tienda", alpha=0.7, palette="tab10")
plt.title("Distribución geográfica de las ventas por tienda")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.grid(True)
plt.tight_layout()
plt.show()
